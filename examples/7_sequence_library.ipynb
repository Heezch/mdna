# %% [markdown]
# # The sequence library
#
# In addition to the ...

# %%
import numpy as np
import mdtraj as md
import matplotlib.pyplot as plt
import nglview as nv

import copy
import nglview as nv
import random
from Bio.SVDSuperimposer import SVDSuperimposer

import mdna
# Out:
# /Users/thor/surfdrive/Projects/mdna/mdna/PMCpy/pmcpy/Evals/PyLk/pylk/writhemap.py:16: UserWarning: Cython version of writhemap (PyLk) not compiled. Defaulting to numba implementation. Consider compiling the cython version.
#   warnings.warn(
# /Users/thor/surfdrive/Projects/mdna/mdna/PMCpy/pmcpy/Evals/PyLk/pylk/eval_link.py:10: UserWarning: Cython version of linkingnumber (PyLk) not compiled. Defaulting to numba implementation. Consider compiling the cython version.
#   warnings.warn(

# %%
# Complemetary base pairs
base_pair_map = {'A':'T','T':'A','G':'C','C':'G','U':'A','D':'G','E':'T','L':'M','M':'L','B':'S','S':'B','Z':'P','P':'Z','CM':'G','AH':'T','GM':'C'}
        
# Load reference bases from the atomic data        
reference_bases = {base: md.load_hdf5(mdna.utils.get_data_file_path(f'./atomic/bases/BDNA_{base}.h5')) for base in base_pair_map.keys()}
bases = list(reference_bases.values())

# Define grid to place the bases
order = [['A', 'T', 'G', 'C'],
        ['AH', 'U', 'GM', 'CM'], 
         ['B', 'S', 'P', 'Z'], 
         ['E', 'D','L', 'M']]


# Initialize the trajectory with the first base
traj = reference_bases[order[0][0]]

# Spacing parameters (in angstroms, adjust as needed)
horizontal_spacing = 1.2  # Spacing between bases within a row
vertical_spacing = 1.5    # Spacing between rows

# Base positions tracking
y_position = 0  # Start at the top-most row and work downwards

for row in order:
    x_position = 0  # Reset x position for each new row
    for i, base in enumerate(row,1):
        if i == 0 and row == order[0]:
            # Already initialized with the first base
            continue
        # Move base in x and y direction
        reference_bases[base].xyz[0] = reference_bases[base].xyz[0] + np.array([-x_position, y_position, 0])
        # Stack the base to the trajectory
        traj = traj.stack(reference_bases[base])
        # Increment x position for the next base in the row
        x_position += horizontal_spacing
    # Decrement y position for the next row to position it below the current one
    y_position -= vertical_spacing

# %% [markdown]
# Visualize the bases

# %%
subtraj = traj.atom_slice(traj.top.select('not element H'))
# subtraj.save_pdb('all_bases.pdb')
# subtraj.save_hdf5('all_bases.h5')
view = nv.show_mdtraj(subtraj)    
view.clear()
view.add_representation('licorice', selection='all')
view
# Out:
# NGLWidget()

# %% [markdown]
# ## How to add a base to the sequence library
#
# Here we show how to align a DNA nucleobase to a specific reference frame.
# We chose the default reference frame at the origin with the base vectors [1,0,0], [0,1,0], [0,0,1].
# This can be useful if you want to add a custom nucleobase to the sequence libary.
# For this we need to isolate the base and add it to the sequence library (./atomic/) and add the pdb/h5 to the reference list in geometry.py `NUCLEOBASE_DICT` which contains all the atoms that belong to the nucleobas part as well as in the modify. Mutate.mutate `base_pair_map` which defines the complementary base partner.
# Here we show an example using a methylated base, but you can use any sequence you want. Just select the residue that you want to isolate.

# %%
def get_base_vectors(res):
       """Compute base vectors from reference base."""
       ref_base = mdna.ReferenceBase(res)
       return np.array([ref_base.b_R, ref_base.b_L, ref_base.b_D, ref_base.b_N]).swapaxes(0,1)

def get_rot_mat_trans(x,y):
    # load super imposer
    sup = SVDSuperimposer()

    # Set the coords, y will be rotated and translated on x
    sup.set(x, y)

    # Do the leastsquared fit
    sup.run()

    # Get the rms
    rms = sup.get_rms()

    # Get rotation (right multiplying!) and the translation
    rot, tran = sup.get_rotran()
    return rot, tran

# Function to calculate positions from origin and vectors
def calculate_positions(triad):
    
    origin = triad[0]
    vectors = triad[1:]
    # Each row in vectors is added to the origin to get the end position
    end_positions = origin + vectors
    # Combine the origin with these end positions
    positions = np.vstack([origin, end_positions])
    return positions


def align_to_ref(traj, ref =  np.array([[0,0,0.0],[1,0,0],[0,1,0],[0,0,1]])):
    vectors = get_base_vectors(traj)
    positions = calculate_positions(vectors[0])
    ref_position =  calculate_positions(ref)
    rot, tran = get_rot_mat_trans(ref_position,positions)
    new_xyz = np.dot(traj.xyz[0], rot) + tran
    traj.xyz[0] = new_xyz
    return traj

# %%
# Create a DNA sequence with a methylated base
dna = mdna.make('GCGCG')
dna.methylate(CpG=True)
traj = dna.get_traj()

# Select the methylated base
meth = traj.atom_slice(traj.top.select('resid 1'))

# Align the methylated base to the reference frame
meth = align_to_ref(meth)

# Save the methylated base
meth.save('./pdbs/BDNA_CM.pdb')
meth.save('./pdbs/BDNA_CM.h5')

# Show the methylated base
view = nv.show_mdtraj(meth)
view.clear()
view.add_ball_and_stick()
view
# Out:
# Start rescaling spline based on requested number of base pairs.
# 	This requires recomputation of the control points to match the desired number of base pairs.
# 	Spline scaled to match the target number of base pairs: 5
#
# Methylate all C in CpG context, superseeds methylations list.
# Methtylating: [1, 3]
# NGLWidget()

# %% [markdown]
# ### Point mutations

# %%
def point_mutation(sequence, position=None, new_nucleotide=None):
    if position is None:
        position = random.randint(0, len(sequence) - 1)
    if new_nucleotide is None:
        nucleotides = ['A', 'T', 'C', 'G']
        new_nucleotide = random.choice([n for n in nucleotides if n != sequence[position]])
    
    mutated_sequence = list(sequence)
    mutated_sequence[position] = new_nucleotide
    return ''.join(mutated_sequence)

def radiate_system(dna, new_sequence, complementary=True, chainids=[0,1], verbose=False):

    pdb = copy.deepcopy(dna.get_traj())   
    if verbose:
        print('--- current stat of the system ---')
    s = dna.sequence
    if len(s) != len(new_sequence):
        raise ValueError('The length of the new sequence does not match the length of the current sequence')
    if verbose:
        print(len(s),s)
        print(''.join(s))
    mutations = mdna.get_mutations(s,new_sequence)
    if verbose:
        print(f'start mutation ---- {mutations} ----')    
    # dna = pdb.atom_slice(pdb.top.select(f'chainid {chainids[0]} {chainids[1]}'))
    # if verbose:
    #     for c in dna.top.chains:
    #         print(c.index, c._residues)

    dna.mutate(mutations,complementary=complementary)
    mutant_sequence = dna.sequence
    if verbose:
        print(mutant_sequence)
        print(''.join(mutant_sequence))
    new_traj = dna.get_traj()
    if verbose:
        for c in new_traj.top.chains:
            print(c.index, c._residues)
        print('--- end radiation ---')
    return new_traj

# %%
# Example usage
save = False
dna = mdna.make('GCGCG')
point_mutations = np.unique([point_mutation(dna.sequence) for _ in range(100)])

for i, new_sequence in enumerate(point_mutations):
    mutant = radiate_system(dna, list(new_sequence))
    print(new_sequence,f'saved as point_mutant_{i}.pdb')
    if save:
        mutant.save(f'./pdbs/point_mutant_{i}.pdb')
# Out:
# Start rescaling spline based on requested number of base pairs.
# 	This requires recomputation of the control points to match the desired number of base pairs.
# 	Spline scaled to match the target number of base pairs: 5
#
# hello
# Pre-deletion residue atoms : [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'"), (8, 'N9'), (9, 'C8'), (10, 'N7'), (11, 'C5'), (12, 'C6'), (13, 'O6'), (14, 'N1'), (15, 'C2'), (16, 'N2'), (17, 'N3'), (18, 'C4')]
# Pre-insertion residue atoms: [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'")]
# Post-insertion residue atoms: [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'"), (8, 'N9'), (9, 'C8'), (10, 'N7'), (11, 'C5'), (12, 'C6'), (13, 'N6'), (14, 'N1'), (15, 'C2'), (16, 'N3'), (17, 'C4')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 8, 3)
# new_xyz shape: (1, 10, 3)
# xyz2 shape: (1, 180, 3)
# Concatenated shape: 198
# Pre-deletion residue atoms : [(179, 'P'), (180, 'OP1'), (181, 'OP2'), (182, "O5'"), (183, "C5'"), (184, "C4'"), (185, "O4'"), (186, "C3'"), (187, "O3'"), (188, "C2'"), (189, "C1'"), (190, 'N1'), (191, 'C2'), (192, 'O2'), (193, 'N3'), (194, 'C4'), (195, 'N4'), (196, 'C5'), (197, 'C6')]
# Pre-insertion residue atoms: [(179, 'P'), (180, 'OP1'), (181, 'OP2'), (182, "O5'"), (183, "C5'"), (184, "C4'"), (185, "O4'"), (186, "C3'"), (187, "O3'"), (188, "C2'"), (189, "C1'")]
# Post-insertion residue atoms: [(179, 'P'), (180, 'OP1'), (181, 'OP2'), (182, "O5'"), (183, "C5'"), (184, "C4'"), (185, "O4'"), (186, "C3'"), (187, "O3'"), (188, "C2'"), (189, "C1'"), (191, 'N1'), (193, 'C2'), (195, 'O2'), (197, 'N3'), (199, 'C4'), (201, 'O4'), (203, 'C5'), (205, 'C7'), (207, 'C6')]
# Original trajectory shape: (1, 198, 3)
# xyz1 shape: (1, 190, 3)
# new_xyz shape: (1, 9, 3)
# xyz2 shape: (1, 0, 3)
# Concatenated shape: 199
# ACGCG saved as point_mutant_0.pdb
# hello
# Pre-deletion residue atoms : [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'"), (8, 'N9'), (9, 'C8'), (10, 'N7'), (11, 'C5'), (12, 'C6'), (13, 'N6'), (14, 'N1'), (15, 'C2'), (16, 'N3'), (17, 'C4')]
# Pre-insertion residue atoms: [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'")]
# Post-insertion residue atoms: [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'"), (8, 'N1'), (9, 'C2'), (10, 'O2'), (11, 'N3'), (12, 'C4'), (13, 'N4'), (14, 'C5'), (15, 'C6')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 8, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 181, 3)
# Concatenated shape: 197
# Pre-deletion residue atoms : [(177, 'P'), (178, 'OP1'), (179, 'OP2'), (180, "O5'"), (181, "C5'"), (182, "C4'"), (183, "O4'"), (184, "C3'"), (185, "O3'"), (186, "C2'"), (187, "C1'"), (188, 'N1'), (189, 'C2'), (190, 'O2'), (191, 'N3'), (192, 'C4'), (193, 'O4'), (194, 'C5'), (195, 'C7'), (196, 'C6')]
# Pre-insertion residue atoms: [(177, 'P'), (178, 'OP1'), (179, 'OP2'), (180, "O5'"), (181, "C5'"), (182, "C4'"), (183, "O4'"), (184, "C3'"), (185, "O3'"), (186, "C2'"), (187, "C1'")]
# Post-insertion residue atoms: [(177, 'P'), (178, 'OP1'), (179, 'OP2'), (180, "O5'"), (181, "C5'"), (182, "C4'"), (183, "O4'"), (184, "C3'"), (185, "O3'"), (186, "C2'"), (187, "C1'"), (189, 'N9'), (191, 'C8'), (193, 'N7'), (195, 'C5'), (197, 'C6'), (199, 'O6'), (201, 'N1'), (203, 'C2'), (205, 'N2'), (207, 'N3'), (209, 'C4')]
# Original trajectory shape: (1, 197, 3)
# xyz1 shape: (1, 188, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 0, 3)
# Concatenated shape: 199
# CCGCG saved as point_mutant_1.pdb
# hello
# Pre-deletion residue atoms : [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'"), (8, 'N1'), (9, 'C2'), (10, 'O2'), (11, 'N3'), (12, 'C4'), (13, 'N4'), (14, 'C5'), (15, 'C6')]
# Pre-insertion residue atoms: [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'")]
# Post-insertion residue atoms: [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'"), (8, 'N9'), (9, 'C8'), (10, 'N7'), (11, 'C5'), (12, 'C6'), (13, 'O6'), (14, 'N1'), (15, 'C2'), (16, 'N2'), (17, 'N3'), (18, 'C4')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 8, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 183, 3)
# Concatenated shape: 202
# Pre-deletion residue atoms : [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'"), (30, 'N1'), (31, 'C2'), (32, 'O2'), (33, 'N3'), (34, 'C4'), (35, 'N4'), (36, 'C5'), (37, 'C6')]
# Pre-insertion residue atoms: [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'")]
# Post-insertion residue atoms: [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'"), (30, 'N9'), (31, 'C8'), (32, 'N7'), (33, 'C5'), (34, 'C6'), (35, 'N6'), (36, 'N1'), (37, 'C2'), (38, 'N3'), (39, 'C4')]
# Original trajectory shape: (1, 202, 3)
# xyz1 shape: (1, 30, 3)
# new_xyz shape: (1, 10, 3)
# xyz2 shape: (1, 164, 3)
# Concatenated shape: 204
# Pre-deletion residue atoms : [(182, 'P'), (183, 'OP1'), (184, 'OP2'), (185, "O5'"), (186, "C5'"), (187, "C4'"), (188, "O4'"), (189, "C3'"), (190, "O3'"), (191, "C2'"), (192, "C1'"), (193, 'N9'), (194, 'C8'), (195, 'N7'), (196, 'C5'), (197, 'C6'), (198, 'O6'), (199, 'N1'), (200, 'C2'), (201, 'N2'), (202, 'N3'), (203, 'C4')]
# Pre-insertion residue atoms: [(182, 'P'), (183, 'OP1'), (184, 'OP2'), (185, "O5'"), (186, "C5'"), (187, "C4'"), (188, "O4'"), (189, "C3'"), (190, "O3'"), (191, "C2'"), (192, "C1'")]
# Post-insertion residue atoms: [(182, 'P'), (183, 'OP1'), (184, 'OP2'), (185, "O5'"), (186, "C5'"), (187, "C4'"), (188, "O4'"), (189, "C3'"), (190, "O3'"), (191, "C2'"), (192, "C1'"), (194, 'N1'), (196, 'C2'), (198, 'O2'), (200, 'N3'), (202, 'C4'), (204, 'N4'), (206, 'C5'), (208, 'C6')]
# Original trajectory shape: (1, 204, 3)
# xyz1 shape: (1, 193, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 0, 3)
# Concatenated shape: 201
# Pre-deletion residue atoms : [(160, 'P'), (161, 'OP1'), (162, 'OP2'), (163, "O5'"), (164, "C5'"), (165, "C4'"), (166, "O4'"), (167, "C3'"), (168, "O3'"), (169, "C2'"), (170, "C1'"), (171, 'N9'), (172, 'C8'), (173, 'N7'), (174, 'C5'), (175, 'C6'), (176, 'O6'), (177, 'N1'), (178, 'C2'), (179, 'N2'), (180, 'N3'), (181, 'C4')]
# Pre-insertion residue atoms: [(160, 'P'), (161, 'OP1'), (162, 'OP2'), (163, "O5'"), (164, "C5'"), (165, "C4'"), (166, "O4'"), (167, "C3'"), (168, "O3'"), (169, "C2'"), (170, "C1'")]
# Post-insertion residue atoms: [(160, 'P'), (161, 'OP1'), (162, 'OP2'), (163, "O5'"), (164, "C5'"), (165, "C4'"), (166, "O4'"), (167, "C3'"), (168, "O3'"), (169, "C2'"), (170, "C1'"), (171, 'N1'), (172, 'C2'), (173, 'O2'), (174, 'N3'), (175, 'C4'), (176, 'O4'), (177, 'C5'), (178, 'C7'), (179, 'C6')]
# Original trajectory shape: (1, 201, 3)
# xyz1 shape: (1, 171, 3)
# new_xyz shape: (1, 9, 3)
# xyz2 shape: (1, 19, 3)
# Concatenated shape: 199
# GAGCG saved as point_mutant_2.pdb
# hello
# Pre-deletion residue atoms : [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'"), (30, 'N9'), (31, 'C8'), (32, 'N7'), (33, 'C5'), (34, 'C6'), (35, 'N6'), (36, 'N1'), (37, 'C2'), (38, 'N3'), (39, 'C4')]
# Pre-insertion residue atoms: [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'")]
# Post-insertion residue atoms: [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'"), (30, 'N1'), (31, 'C2'), (32, 'O2'), (33, 'N3'), (34, 'C4'), (35, 'N4'), (36, 'C5'), (37, 'C6')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 30, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 159, 3)
# Concatenated shape: 197
# Pre-deletion residue atoms : [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'"), (49, 'N9'), (50, 'C8'), (51, 'N7'), (52, 'C5'), (53, 'C6'), (54, 'O6'), (55, 'N1'), (56, 'C2'), (57, 'N2'), (58, 'N3'), (59, 'C4')]
# Pre-insertion residue atoms: [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'")]
# Post-insertion residue atoms: [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'"), (49, 'N9'), (50, 'C8'), (51, 'N7'), (52, 'C5'), (53, 'C6'), (54, 'N6'), (55, 'N1'), (56, 'C2'), (57, 'N3'), (58, 'C4')]
# Original trajectory shape: (1, 197, 3)
# xyz1 shape: (1, 49, 3)
# new_xyz shape: (1, 10, 3)
# xyz2 shape: (1, 137, 3)
# Concatenated shape: 196
# Pre-deletion residue atoms : [(157, 'P'), (158, 'OP1'), (159, 'OP2'), (160, "O5'"), (161, "C5'"), (162, "C4'"), (163, "O4'"), (164, "C3'"), (165, "O3'"), (166, "C2'"), (167, "C1'"), (168, 'N1'), (169, 'C2'), (170, 'O2'), (171, 'N3'), (172, 'C4'), (173, 'O4'), (174, 'C5'), (175, 'C7'), (176, 'C6')]
# Pre-insertion residue atoms: [(157, 'P'), (158, 'OP1'), (159, 'OP2'), (160, "O5'"), (161, "C5'"), (162, "C4'"), (163, "O4'"), (164, "C3'"), (165, "O3'"), (166, "C2'"), (167, "C1'")]
# Post-insertion residue atoms: [(157, 'P'), (158, 'OP1'), (159, 'OP2'), (160, "O5'"), (161, "C5'"), (162, "C4'"), (163, "O4'"), (164, "C3'"), (165, "O3'"), (166, "C2'"), (167, "C1'"), (168, 'N9'), (169, 'C8'), (170, 'N7'), (171, 'C5'), (172, 'C6'), (173, 'O6'), (174, 'N1'), (175, 'C2'), (176, 'N2'), (177, 'N3'), (178, 'C4')]
# Original trajectory shape: (1, 196, 3)
# xyz1 shape: (1, 168, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 19, 3)
# Concatenated shape: 198
# Pre-deletion residue atoms : [(138, 'P'), (139, 'OP1'), (140, 'OP2'), (141, "O5'"), (142, "C5'"), (143, "C4'"), (144, "O4'"), (145, "C3'"), (146, "O3'"), (147, "C2'"), (148, "C1'"), (149, 'N1'), (150, 'C2'), (151, 'O2'), (152, 'N3'), (153, 'C4'), (154, 'N4'), (155, 'C5'), (156, 'C6')]
# Pre-insertion residue atoms: [(138, 'P'), (139, 'OP1'), (140, 'OP2'), (141, "O5'"), (142, "C5'"), (143, "C4'"), (144, "O4'"), (145, "C3'"), (146, "O3'"), (147, "C2'"), (148, "C1'")]
# Post-insertion residue atoms: [(138, 'P'), (139, 'OP1'), (140, 'OP2'), (141, "O5'"), (142, "C5'"), (143, "C4'"), (144, "O4'"), (145, "C3'"), (146, "O3'"), (147, "C2'"), (148, "C1'"), (149, 'N1'), (150, 'C2'), (151, 'O2'), (152, 'N3'), (153, 'C4'), (154, 'O4'), (155, 'C5'), (156, 'C7'), (157, 'C6')]
# Original trajectory shape: (1, 198, 3)
# xyz1 shape: (1, 149, 3)
# new_xyz shape: (1, 9, 3)
# xyz2 shape: (1, 41, 3)
# Concatenated shape: 199
# GCACG saved as point_mutant_3.pdb
# hello
# Pre-deletion residue atoms : [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'"), (49, 'N9'), (50, 'C8'), (51, 'N7'), (52, 'C5'), (53, 'C6'), (54, 'N6'), (55, 'N1'), (56, 'C2'), (57, 'N3'), (58, 'C4')]
# Pre-insertion residue atoms: [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'")]
# Post-insertion residue atoms: [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'"), (49, 'N1'), (50, 'C2'), (51, 'O2'), (52, 'N3'), (53, 'C4'), (54, 'N4'), (55, 'C5'), (56, 'C6')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 49, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 140, 3)
# Concatenated shape: 197
# Pre-deletion residue atoms : [(136, 'P'), (137, 'OP1'), (138, 'OP2'), (139, "O5'"), (140, "C5'"), (141, "C4'"), (142, "O4'"), (143, "C3'"), (144, "O3'"), (145, "C2'"), (146, "C1'"), (147, 'N1'), (148, 'C2'), (149, 'O2'), (150, 'N3'), (151, 'C4'), (152, 'O4'), (153, 'C5'), (154, 'C7'), (155, 'C6')]
# Pre-insertion residue atoms: [(136, 'P'), (137, 'OP1'), (138, 'OP2'), (139, "O5'"), (140, "C5'"), (141, "C4'"), (142, "O4'"), (143, "C3'"), (144, "O3'"), (145, "C2'"), (146, "C1'")]
# Post-insertion residue atoms: [(136, 'P'), (137, 'OP1'), (138, 'OP2'), (139, "O5'"), (140, "C5'"), (141, "C4'"), (142, "O4'"), (143, "C3'"), (144, "O3'"), (145, "C2'"), (146, "C1'"), (147, 'N9'), (148, 'C8'), (149, 'N7'), (150, 'C5'), (151, 'C6'), (152, 'O6'), (153, 'N1'), (154, 'C2'), (155, 'N2'), (156, 'N3'), (157, 'C4')]
# Original trajectory shape: (1, 197, 3)
# xyz1 shape: (1, 147, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 41, 3)
# Concatenated shape: 199
# GCCCG saved as point_mutant_4.pdb
# hello
# Pre-deletion residue atoms : [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'"), (49, 'N1'), (50, 'C2'), (51, 'O2'), (52, 'N3'), (53, 'C4'), (54, 'N4'), (55, 'C5'), (56, 'C6')]
# Pre-insertion residue atoms: [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'")]
# Post-insertion residue atoms: [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'"), (49, 'N9'), (50, 'C8'), (51, 'N7'), (52, 'C5'), (53, 'C6'), (54, 'O6'), (55, 'N1'), (56, 'C2'), (57, 'N2'), (58, 'N3'), (59, 'C4')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 49, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 142, 3)
# Concatenated shape: 202
# Pre-deletion residue atoms : [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'"), (71, 'N1'), (72, 'C2'), (73, 'O2'), (74, 'N3'), (75, 'C4'), (76, 'N4'), (77, 'C5'), (78, 'C6')]
# Pre-insertion residue atoms: [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'")]
# Post-insertion residue atoms: [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'"), (71, 'N9'), (72, 'C8'), (73, 'N7'), (74, 'C5'), (75, 'C6'), (76, 'N6'), (77, 'N1'), (78, 'C2'), (79, 'N3'), (80, 'C4')]
# Original trajectory shape: (1, 202, 3)
# xyz1 shape: (1, 71, 3)
# new_xyz shape: (1, 10, 3)
# xyz2 shape: (1, 123, 3)
# Concatenated shape: 204
# Pre-deletion residue atoms : [(141, 'P'), (142, 'OP1'), (143, 'OP2'), (144, "O5'"), (145, "C5'"), (146, "C4'"), (147, "O4'"), (148, "C3'"), (149, "O3'"), (150, "C2'"), (151, "C1'"), (152, 'N9'), (153, 'C8'), (154, 'N7'), (155, 'C5'), (156, 'C6'), (157, 'O6'), (158, 'N1'), (159, 'C2'), (160, 'N2'), (161, 'N3'), (162, 'C4')]
# Pre-insertion residue atoms: [(141, 'P'), (142, 'OP1'), (143, 'OP2'), (144, "O5'"), (145, "C5'"), (146, "C4'"), (147, "O4'"), (148, "C3'"), (149, "O3'"), (150, "C2'"), (151, "C1'")]
# Post-insertion residue atoms: [(141, 'P'), (142, 'OP1'), (143, 'OP2'), (144, "O5'"), (145, "C5'"), (146, "C4'"), (147, "O4'"), (148, "C3'"), (149, "O3'"), (150, "C2'"), (151, "C1'"), (152, 'N1'), (153, 'C2'), (154, 'O2'), (155, 'N3'), (156, 'C4'), (157, 'N4'), (158, 'C5'), (159, 'C6')]
# Original trajectory shape: (1, 204, 3)
# xyz1 shape: (1, 152, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 41, 3)
# Concatenated shape: 201
# Pre-deletion residue atoms : [(119, 'P'), (120, 'OP1'), (121, 'OP2'), (122, "O5'"), (123, "C5'"), (124, "C4'"), (125, "O4'"), (126, "C3'"), (127, "O3'"), (128, "C2'"), (129, "C1'"), (130, 'N9'), (131, 'C8'), (132, 'N7'), (133, 'C5'), (134, 'C6'), (135, 'O6'), (136, 'N1'), (137, 'C2'), (138, 'N2'), (139, 'N3'), (140, 'C4')]
# Pre-insertion residue atoms: [(119, 'P'), (120, 'OP1'), (121, 'OP2'), (122, "O5'"), (123, "C5'"), (124, "C4'"), (125, "O4'"), (126, "C3'"), (127, "O3'"), (128, "C2'"), (129, "C1'")]
# Post-insertion residue atoms: [(119, 'P'), (120, 'OP1'), (121, 'OP2'), (122, "O5'"), (123, "C5'"), (124, "C4'"), (125, "O4'"), (126, "C3'"), (127, "O3'"), (128, "C2'"), (129, "C1'"), (130, 'N1'), (131, 'C2'), (132, 'O2'), (133, 'N3'), (134, 'C4'), (135, 'O4'), (136, 'C5'), (137, 'C7'), (138, 'C6')]
# Original trajectory shape: (1, 201, 3)
# xyz1 shape: (1, 130, 3)
# new_xyz shape: (1, 9, 3)
# xyz2 shape: (1, 60, 3)
# Concatenated shape: 199
# GCGAG saved as point_mutant_5.pdb
# hello
# Pre-deletion residue atoms : [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'"), (71, 'N9'), (72, 'C8'), (73, 'N7'), (74, 'C5'), (75, 'C6'), (76, 'N6'), (77, 'N1'), (78, 'C2'), (79, 'N3'), (80, 'C4')]
# Pre-insertion residue atoms: [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'")]
# Post-insertion residue atoms: [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'"), (71, 'N1'), (72, 'C2'), (73, 'O2'), (74, 'N3'), (75, 'C4'), (76, 'N4'), (77, 'C5'), (78, 'C6')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 71, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 118, 3)
# Concatenated shape: 197
# Pre-deletion residue atoms : [(79, 'P'), (80, 'OP1'), (81, 'OP2'), (82, "O5'"), (83, "C5'"), (84, "C4'"), (85, "O4'"), (86, "C3'"), (87, "O3'"), (88, "C2'"), (89, "C1'"), (90, 'N9'), (91, 'C8'), (92, 'N7'), (93, 'C5'), (94, 'C6'), (95, 'O6'), (96, 'N1'), (97, 'C2'), (98, 'N2'), (99, 'N3'), (100, 'C4')]
# Pre-insertion residue atoms: [(79, 'P'), (80, 'OP1'), (81, 'OP2'), (82, "O5'"), (83, "C5'"), (84, "C4'"), (85, "O4'"), (86, "C3'"), (87, "O3'"), (88, "C2'"), (89, "C1'")]
# Post-insertion residue atoms: [(79, 'P'), (80, 'OP1'), (81, 'OP2'), (82, "O5'"), (83, "C5'"), (84, "C4'"), (85, "O4'"), (86, "C3'"), (87, "O3'"), (88, "C2'"), (89, "C1'"), (90, 'N9'), (91, 'C8'), (92, 'N7'), (93, 'C5'), (94, 'C6'), (95, 'N6'), (96, 'N1'), (97, 'C2'), (98, 'N3'), (99, 'C4')]
# Original trajectory shape: (1, 197, 3)
# xyz1 shape: (1, 90, 3)
# new_xyz shape: (1, 10, 3)
# xyz2 shape: (1, 96, 3)
# Concatenated shape: 196
# Pre-deletion residue atoms : [(116, 'P'), (117, 'OP1'), (118, 'OP2'), (119, "O5'"), (120, "C5'"), (121, "C4'"), (122, "O4'"), (123, "C3'"), (124, "O3'"), (125, "C2'"), (126, "C1'"), (127, 'N1'), (128, 'C2'), (129, 'O2'), (130, 'N3'), (131, 'C4'), (132, 'O4'), (133, 'C5'), (134, 'C7'), (135, 'C6')]
# Pre-insertion residue atoms: [(116, 'P'), (117, 'OP1'), (118, 'OP2'), (119, "O5'"), (120, "C5'"), (121, "C4'"), (122, "O4'"), (123, "C3'"), (124, "O3'"), (125, "C2'"), (126, "C1'")]
# Post-insertion residue atoms: [(116, 'P'), (117, 'OP1'), (118, 'OP2'), (119, "O5'"), (120, "C5'"), (121, "C4'"), (122, "O4'"), (123, "C3'"), (124, "O3'"), (125, "C2'"), (126, "C1'"), (127, 'N9'), (128, 'C8'), (129, 'N7'), (130, 'C5'), (131, 'C6'), (132, 'O6'), (133, 'N1'), (134, 'C2'), (135, 'N2'), (136, 'N3'), (137, 'C4')]
# Original trajectory shape: (1, 196, 3)
# xyz1 shape: (1, 127, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 60, 3)
# Concatenated shape: 198
# Pre-deletion residue atoms : [(100, "O5'"), (101, "C5'"), (102, "C4'"), (103, "O4'"), (104, "C3'"), (105, "O3'"), (106, "C2'"), (107, "C1'"), (108, 'N1'), (109, 'C2'), (110, 'O2'), (111, 'N3'), (112, 'C4'), (113, 'N4'), (114, 'C5'), (115, 'C6')]
# Pre-insertion residue atoms: [(100, "O5'"), (101, "C5'"), (102, "C4'"), (103, "O4'"), (104, "C3'"), (105, "O3'"), (106, "C2'"), (107, "C1'")]
# Post-insertion residue atoms: [(100, "O5'"), (101, "C5'"), (102, "C4'"), (103, "O4'"), (104, "C3'"), (105, "O3'"), (106, "C2'"), (107, "C1'"), (108, 'N1'), (109, 'C2'), (110, 'O2'), (111, 'N3'), (112, 'C4'), (113, 'O4'), (114, 'C5'), (115, 'C7'), (116, 'C6')]
# Original trajectory shape: (1, 198, 3)
# xyz1 shape: (1, 108, 3)
# new_xyz shape: (1, 9, 3)
# xyz2 shape: (1, 82, 3)
# Concatenated shape: 199
# GCGCA saved as point_mutant_6.pdb
# hello
# Pre-deletion residue atoms : [(79, 'P'), (80, 'OP1'), (81, 'OP2'), (82, "O5'"), (83, "C5'"), (84, "C4'"), (85, "O4'"), (86, "C3'"), (87, "O3'"), (88, "C2'"), (89, "C1'"), (90, 'N9'), (91, 'C8'), (92, 'N7'), (93, 'C5'), (94, 'C6'), (95, 'N6'), (96, 'N1'), (97, 'C2'), (98, 'N3'), (99, 'C4')]
# Pre-insertion residue atoms: [(79, 'P'), (80, 'OP1'), (81, 'OP2'), (82, "O5'"), (83, "C5'"), (84, "C4'"), (85, "O4'"), (86, "C3'"), (87, "O3'"), (88, "C2'"), (89, "C1'")]
# Post-insertion residue atoms: [(79, 'P'), (80, 'OP1'), (81, 'OP2'), (82, "O5'"), (83, "C5'"), (84, "C4'"), (85, "O4'"), (86, "C3'"), (87, "O3'"), (88, "C2'"), (89, "C1'"), (90, 'N1'), (91, 'C2'), (92, 'O2'), (93, 'N3'), (94, 'C4'), (95, 'N4'), (96, 'C5'), (97, 'C6')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 90, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 99, 3)
# Concatenated shape: 197
# Pre-deletion residue atoms : [(98, "O5'"), (99, "C5'"), (100, "C4'"), (101, "O4'"), (102, "C3'"), (103, "O3'"), (104, "C2'"), (105, "C1'"), (106, 'N1'), (107, 'C2'), (108, 'O2'), (109, 'N3'), (110, 'C4'), (111, 'O4'), (112, 'C5'), (113, 'C7'), (114, 'C6')]
# Pre-insertion residue atoms: [(98, "O5'"), (99, "C5'"), (100, "C4'"), (101, "O4'"), (102, "C3'"), (103, "O3'"), (104, "C2'"), (105, "C1'")]
# Post-insertion residue atoms: [(98, "O5'"), (99, "C5'"), (100, "C4'"), (101, "O4'"), (102, "C3'"), (103, "O3'"), (104, "C2'"), (105, "C1'"), (106, 'N9'), (107, 'C8'), (108, 'N7'), (109, 'C5'), (110, 'C6'), (111, 'O6'), (112, 'N1'), (113, 'C2'), (114, 'N2'), (115, 'N3'), (116, 'C4')]
# Original trajectory shape: (1, 197, 3)
# xyz1 shape: (1, 106, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 82, 3)
# Concatenated shape: 199
# GCGCC saved as point_mutant_7.pdb
# hello
# Pre-deletion residue atoms : [(79, 'P'), (80, 'OP1'), (81, 'OP2'), (82, "O5'"), (83, "C5'"), (84, "C4'"), (85, "O4'"), (86, "C3'"), (87, "O3'"), (88, "C2'"), (89, "C1'"), (90, 'N1'), (91, 'C2'), (92, 'O2'), (93, 'N3'), (94, 'C4'), (95, 'N4'), (96, 'C5'), (97, 'C6')]
# Pre-insertion residue atoms: [(79, 'P'), (80, 'OP1'), (81, 'OP2'), (82, "O5'"), (83, "C5'"), (84, "C4'"), (85, "O4'"), (86, "C3'"), (87, "O3'"), (88, "C2'"), (89, "C1'")]
# Post-insertion residue atoms: [(79, 'P'), (80, 'OP1'), (81, 'OP2'), (82, "O5'"), (83, "C5'"), (84, "C4'"), (85, "O4'"), (86, "C3'"), (87, "O3'"), (88, "C2'"), (89, "C1'"), (90, 'N1'), (91, 'C2'), (92, 'O2'), (93, 'N3'), (94, 'C4'), (95, 'O4'), (96, 'C5'), (97, 'C7'), (98, 'C6')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 90, 3)
# new_xyz shape: (1, 9, 3)
# xyz2 shape: (1, 101, 3)
# Concatenated shape: 200
# Pre-deletion residue atoms : [(99, "O5'"), (100, "C5'"), (101, "C4'"), (102, "O4'"), (103, "C3'"), (104, "O3'"), (105, "C2'"), (106, "C1'"), (107, 'N9'), (108, 'C8'), (109, 'N7'), (110, 'C5'), (111, 'C6'), (112, 'O6'), (113, 'N1'), (114, 'C2'), (115, 'N2'), (116, 'N3'), (117, 'C4')]
# Pre-insertion residue atoms: [(99, "O5'"), (100, "C5'"), (101, "C4'"), (102, "O4'"), (103, "C3'"), (104, "O3'"), (105, "C2'"), (106, "C1'")]
# Post-insertion residue atoms: [(99, "O5'"), (100, "C5'"), (101, "C4'"), (102, "O4'"), (103, "C3'"), (104, "O3'"), (105, "C2'"), (106, "C1'"), (107, 'N9'), (108, 'C8'), (109, 'N7'), (110, 'C5'), (111, 'C6'), (112, 'N6'), (113, 'N1'), (114, 'C2'), (115, 'N3'), (116, 'C4')]
# Original trajectory shape: (1, 200, 3)
# xyz1 shape: (1, 107, 3)
# new_xyz shape: (1, 10, 3)
# xyz2 shape: (1, 82, 3)
# Concatenated shape: 199
# GCGCT saved as point_mutant_8.pdb
# hello
# Pre-deletion residue atoms : [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'"), (71, 'N1'), (72, 'C2'), (73, 'O2'), (74, 'N3'), (75, 'C4'), (76, 'N4'), (77, 'C5'), (78, 'C6')]
# Pre-insertion residue atoms: [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'")]
# Post-insertion residue atoms: [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'"), (71, 'N9'), (72, 'C8'), (73, 'N7'), (74, 'C5'), (75, 'C6'), (76, 'O6'), (77, 'N1'), (78, 'C2'), (79, 'N2'), (80, 'N3'), (81, 'C4')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 71, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 120, 3)
# Concatenated shape: 202
# Pre-deletion residue atoms : [(82, 'P'), (83, 'OP1'), (84, 'OP2'), (85, "O5'"), (86, "C5'"), (87, "C4'"), (88, "O4'"), (89, "C3'"), (90, "O3'"), (91, "C2'"), (92, "C1'"), (93, 'N1'), (94, 'C2'), (95, 'O2'), (96, 'N3'), (97, 'C4'), (98, 'O4'), (99, 'C5'), (100, 'C7'), (101, 'C6')]
# Pre-insertion residue atoms: [(82, 'P'), (83, 'OP1'), (84, 'OP2'), (85, "O5'"), (86, "C5'"), (87, "C4'"), (88, "O4'"), (89, "C3'"), (90, "O3'"), (91, "C2'"), (92, "C1'")]
# Post-insertion residue atoms: [(82, 'P'), (83, 'OP1'), (84, 'OP2'), (85, "O5'"), (86, "C5'"), (87, "C4'"), (88, "O4'"), (89, "C3'"), (90, "O3'"), (91, "C2'"), (92, "C1'"), (93, 'N9'), (94, 'C8'), (95, 'N7'), (96, 'C5'), (97, 'C6'), (98, 'O6'), (99, 'N1'), (100, 'C2'), (101, 'N2'), (102, 'N3'), (103, 'C4')]
# Original trajectory shape: (1, 202, 3)
# xyz1 shape: (1, 93, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 100, 3)
# Concatenated shape: 204
# Pre-deletion residue atoms : [(122, 'P'), (123, 'OP1'), (124, 'OP2'), (125, "O5'"), (126, "C5'"), (127, "C4'"), (128, "O4'"), (129, "C3'"), (130, "O3'"), (131, "C2'"), (132, "C1'"), (133, 'N9'), (134, 'C8'), (135, 'N7'), (136, 'C5'), (137, 'C6'), (138, 'O6'), (139, 'N1'), (140, 'C2'), (141, 'N2'), (142, 'N3'), (143, 'C4')]
# Pre-insertion residue atoms: [(122, 'P'), (123, 'OP1'), (124, 'OP2'), (125, "O5'"), (126, "C5'"), (127, "C4'"), (128, "O4'"), (129, "C3'"), (130, "O3'"), (131, "C2'"), (132, "C1'")]
# Post-insertion residue atoms: [(122, 'P'), (123, 'OP1'), (124, 'OP2'), (125, "O5'"), (126, "C5'"), (127, "C4'"), (128, "O4'"), (129, "C3'"), (130, "O3'"), (131, "C2'"), (132, "C1'"), (133, 'N1'), (134, 'C2'), (135, 'O2'), (136, 'N3'), (137, 'C4'), (138, 'N4'), (139, 'C5'), (140, 'C6')]
# Original trajectory shape: (1, 204, 3)
# xyz1 shape: (1, 133, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 60, 3)
# Concatenated shape: 201
# Pre-deletion residue atoms : [(104, "O5'"), (105, "C5'"), (106, "C4'"), (107, "O4'"), (108, "C3'"), (109, "O3'"), (110, "C2'"), (111, "C1'"), (112, 'N9'), (113, 'C8'), (114, 'N7'), (115, 'C5'), (116, 'C6'), (117, 'N6'), (118, 'N1'), (119, 'C2'), (120, 'N3'), (121, 'C4')]
# Pre-insertion residue atoms: [(104, "O5'"), (105, "C5'"), (106, "C4'"), (107, "O4'"), (108, "C3'"), (109, "O3'"), (110, "C2'"), (111, "C1'")]
# Post-insertion residue atoms: [(104, "O5'"), (105, "C5'"), (106, "C4'"), (107, "O4'"), (108, "C3'"), (109, "O3'"), (110, "C2'"), (111, "C1'"), (112, 'N1'), (113, 'C2'), (114, 'O2'), (115, 'N3'), (116, 'C4'), (117, 'N4'), (118, 'C5'), (119, 'C6')]
# Original trajectory shape: (1, 201, 3)
# xyz1 shape: (1, 112, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 79, 3)
# Concatenated shape: 199
# GCGGG saved as point_mutant_9.pdb
# hello
# Pre-deletion residue atoms : [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'"), (71, 'N9'), (72, 'C8'), (73, 'N7'), (74, 'C5'), (75, 'C6'), (76, 'O6'), (77, 'N1'), (78, 'C2'), (79, 'N2'), (80, 'N3'), (81, 'C4')]
# Pre-insertion residue atoms: [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'")]
# Post-insertion residue atoms: [(60, 'P'), (61, 'OP1'), (62, 'OP2'), (63, "O5'"), (64, "C5'"), (65, "C4'"), (66, "O4'"), (67, "C3'"), (68, "O3'"), (69, "C2'"), (70, "C1'"), (71, 'N1'), (72, 'C2'), (73, 'O2'), (74, 'N3'), (75, 'C4'), (76, 'O4'), (77, 'C5'), (78, 'C7'), (79, 'C6')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 71, 3)
# new_xyz shape: (1, 9, 3)
# xyz2 shape: (1, 117, 3)
# Concatenated shape: 197
# Pre-deletion residue atoms : [(118, 'P'), (119, 'OP1'), (120, 'OP2'), (121, "O5'"), (122, "C5'"), (123, "C4'"), (124, "O4'"), (125, "C3'"), (126, "O3'"), (127, "C2'"), (128, "C1'"), (129, 'N1'), (130, 'C2'), (131, 'O2'), (132, 'N3'), (133, 'C4'), (134, 'N4'), (135, 'C5'), (136, 'C6')]
# Pre-insertion residue atoms: [(118, 'P'), (119, 'OP1'), (120, 'OP2'), (121, "O5'"), (122, "C5'"), (123, "C4'"), (124, "O4'"), (125, "C3'"), (126, "O3'"), (127, "C2'"), (128, "C1'")]
# Post-insertion residue atoms: [(118, 'P'), (119, 'OP1'), (120, 'OP2'), (121, "O5'"), (122, "C5'"), (123, "C4'"), (124, "O4'"), (125, "C3'"), (126, "O3'"), (127, "C2'"), (128, "C1'"), (129, 'N9'), (130, 'C8'), (131, 'N7'), (132, 'C5'), (133, 'C6'), (134, 'N6'), (135, 'N1'), (136, 'C2'), (137, 'N3'), (138, 'C4')]
# Original trajectory shape: (1, 197, 3)
# xyz1 shape: (1, 129, 3)
# new_xyz shape: (1, 10, 3)
# xyz2 shape: (1, 60, 3)
# Concatenated shape: 199
# GCGTG saved as point_mutant_10.pdb
# hello
# Pre-deletion residue atoms : [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'"), (49, 'N9'), (50, 'C8'), (51, 'N7'), (52, 'C5'), (53, 'C6'), (54, 'O6'), (55, 'N1'), (56, 'C2'), (57, 'N2'), (58, 'N3'), (59, 'C4')]
# Pre-insertion residue atoms: [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'")]
# Post-insertion residue atoms: [(38, 'P'), (39, 'OP1'), (40, 'OP2'), (41, "O5'"), (42, "C5'"), (43, "C4'"), (44, "O4'"), (45, "C3'"), (46, "O3'"), (47, "C2'"), (48, "C1'"), (49, 'N1'), (50, 'C2'), (51, 'O2'), (52, 'N3'), (53, 'C4'), (54, 'O4'), (55, 'C5'), (56, 'C7'), (57, 'C6')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 49, 3)
# new_xyz shape: (1, 9, 3)
# xyz2 shape: (1, 139, 3)
# Concatenated shape: 197
# Pre-deletion residue atoms : [(58, 'P'), (59, 'OP1'), (60, 'OP2'), (61, "O5'"), (62, "C5'"), (63, "C4'"), (64, "O4'"), (65, "C3'"), (66, "O3'"), (67, "C2'"), (68, "C1'"), (69, 'N1'), (70, 'C2'), (71, 'O2'), (72, 'N3'), (73, 'C4'), (74, 'O4'), (75, 'C5'), (76, 'C7'), (77, 'C6')]
# Pre-insertion residue atoms: [(58, 'P'), (59, 'OP1'), (60, 'OP2'), (61, "O5'"), (62, "C5'"), (63, "C4'"), (64, "O4'"), (65, "C3'"), (66, "O3'"), (67, "C2'"), (68, "C1'")]
# Post-insertion residue atoms: [(58, 'P'), (59, 'OP1'), (60, 'OP2'), (61, "O5'"), (62, "C5'"), (63, "C4'"), (64, "O4'"), (65, "C3'"), (66, "O3'"), (67, "C2'"), (68, "C1'"), (69, 'N1'), (70, 'C2'), (71, 'O2'), (72, 'N3'), (73, 'C4'), (74, 'N4'), (75, 'C5'), (76, 'C6')]
# Original trajectory shape: (1, 197, 3)
# xyz1 shape: (1, 69, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 119, 3)
# Concatenated shape: 196
# Pre-deletion residue atoms : [(136, 'P'), (137, 'OP1'), (138, 'OP2'), (139, "O5'"), (140, "C5'"), (141, "C4'"), (142, "O4'"), (143, "C3'"), (144, "O3'"), (145, "C2'"), (146, "C1'"), (147, 'N1'), (148, 'C2'), (149, 'O2'), (150, 'N3'), (151, 'C4'), (152, 'N4'), (153, 'C5'), (154, 'C6')]
# Pre-insertion residue atoms: [(136, 'P'), (137, 'OP1'), (138, 'OP2'), (139, "O5'"), (140, "C5'"), (141, "C4'"), (142, "O4'"), (143, "C3'"), (144, "O3'"), (145, "C2'"), (146, "C1'")]
# Post-insertion residue atoms: [(136, 'P'), (137, 'OP1'), (138, 'OP2'), (139, "O5'"), (140, "C5'"), (141, "C4'"), (142, "O4'"), (143, "C3'"), (144, "O3'"), (145, "C2'"), (146, "C1'"), (147, 'N9'), (148, 'C8'), (149, 'N7'), (150, 'C5'), (151, 'C6'), (152, 'N6'), (153, 'N1'), (154, 'C2'), (155, 'N3'), (156, 'C4')]
# Original trajectory shape: (1, 196, 3)
# xyz1 shape: (1, 147, 3)
# new_xyz shape: (1, 10, 3)
# xyz2 shape: (1, 41, 3)
# Concatenated shape: 198
# Pre-deletion residue atoms : [(115, 'P'), (116, 'OP1'), (117, 'OP2'), (118, "O5'"), (119, "C5'"), (120, "C4'"), (121, "O4'"), (122, "C3'"), (123, "O3'"), (124, "C2'"), (125, "C1'"), (126, 'N9'), (127, 'C8'), (128, 'N7'), (129, 'C5'), (130, 'C6'), (131, 'N6'), (132, 'N1'), (133, 'C2'), (134, 'N3'), (135, 'C4')]
# Pre-insertion residue atoms: [(115, 'P'), (116, 'OP1'), (117, 'OP2'), (118, "O5'"), (119, "C5'"), (120, "C4'"), (121, "O4'"), (122, "C3'"), (123, "O3'"), (124, "C2'"), (125, "C1'")]
# Post-insertion residue atoms: [(115, 'P'), (116, 'OP1'), (117, 'OP2'), (118, "O5'"), (119, "C5'"), (120, "C4'"), (121, "O4'"), (122, "C3'"), (123, "O3'"), (124, "C2'"), (125, "C1'"), (126, 'N9'), (127, 'C8'), (128, 'N7'), (129, 'C5'), (130, 'C6'), (131, 'O6'), (132, 'N1'), (133, 'C2'), (134, 'N2'), (135, 'N3'), (136, 'C4')]
# Original trajectory shape: (1, 198, 3)
# xyz1 shape: (1, 126, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 62, 3)
# Concatenated shape: 199
# GCTCG saved as point_mutant_11.pdb
# hello
# Pre-deletion residue atoms : [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'"), (30, 'N1'), (31, 'C2'), (32, 'O2'), (33, 'N3'), (34, 'C4'), (35, 'N4'), (36, 'C5'), (37, 'C6')]
# Pre-insertion residue atoms: [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'")]
# Post-insertion residue atoms: [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'"), (30, 'N9'), (31, 'C8'), (32, 'N7'), (33, 'C5'), (34, 'C6'), (35, 'O6'), (36, 'N1'), (37, 'C2'), (38, 'N2'), (39, 'N3'), (40, 'C4')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 30, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 161, 3)
# Concatenated shape: 202
# Pre-deletion residue atoms : [(41, 'P'), (42, 'OP1'), (43, 'OP2'), (44, "O5'"), (45, "C5'"), (46, "C4'"), (47, "O4'"), (48, "C3'"), (49, "O3'"), (50, "C2'"), (51, "C1'"), (52, 'N1'), (53, 'C2'), (54, 'O2'), (55, 'N3'), (56, 'C4'), (57, 'O4'), (58, 'C5'), (59, 'C7'), (60, 'C6')]
# Pre-insertion residue atoms: [(41, 'P'), (42, 'OP1'), (43, 'OP2'), (44, "O5'"), (45, "C5'"), (46, "C4'"), (47, "O4'"), (48, "C3'"), (49, "O3'"), (50, "C2'"), (51, "C1'")]
# Post-insertion residue atoms: [(41, 'P'), (42, 'OP1'), (43, 'OP2'), (44, "O5'"), (45, "C5'"), (46, "C4'"), (47, "O4'"), (48, "C3'"), (49, "O3'"), (50, "C2'"), (51, "C1'"), (52, 'N9'), (53, 'C8'), (54, 'N7'), (55, 'C5'), (56, 'C6'), (57, 'O6'), (58, 'N1'), (59, 'C2'), (60, 'N2'), (61, 'N3'), (62, 'C4')]
# Original trajectory shape: (1, 202, 3)
# xyz1 shape: (1, 52, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 141, 3)
# Concatenated shape: 204
# Pre-deletion residue atoms : [(163, 'P'), (164, 'OP1'), (165, 'OP2'), (166, "O5'"), (167, "C5'"), (168, "C4'"), (169, "O4'"), (170, "C3'"), (171, "O3'"), (172, "C2'"), (173, "C1'"), (174, 'N9'), (175, 'C8'), (176, 'N7'), (177, 'C5'), (178, 'C6'), (179, 'O6'), (180, 'N1'), (181, 'C2'), (182, 'N2'), (183, 'N3'), (184, 'C4')]
# Pre-insertion residue atoms: [(163, 'P'), (164, 'OP1'), (165, 'OP2'), (166, "O5'"), (167, "C5'"), (168, "C4'"), (169, "O4'"), (170, "C3'"), (171, "O3'"), (172, "C2'"), (173, "C1'")]
# Post-insertion residue atoms: [(163, 'P'), (164, 'OP1'), (165, 'OP2'), (166, "O5'"), (167, "C5'"), (168, "C4'"), (169, "O4'"), (170, "C3'"), (171, "O3'"), (172, "C2'"), (173, "C1'"), (174, 'N1'), (175, 'C2'), (176, 'O2'), (177, 'N3'), (178, 'C4'), (179, 'N4'), (180, 'C5'), (181, 'C6')]
# Original trajectory shape: (1, 204, 3)
# xyz1 shape: (1, 174, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 19, 3)
# Concatenated shape: 201
# Pre-deletion residue atoms : [(142, 'P'), (143, 'OP1'), (144, 'OP2'), (145, "O5'"), (146, "C5'"), (147, "C4'"), (148, "O4'"), (149, "C3'"), (150, "O3'"), (151, "C2'"), (152, "C1'"), (153, 'N9'), (154, 'C8'), (155, 'N7'), (156, 'C5'), (157, 'C6'), (158, 'N6'), (159, 'N1'), (160, 'C2'), (161, 'N3'), (162, 'C4')]
# Pre-insertion residue atoms: [(142, 'P'), (143, 'OP1'), (144, 'OP2'), (145, "O5'"), (146, "C5'"), (147, "C4'"), (148, "O4'"), (149, "C3'"), (150, "O3'"), (151, "C2'"), (152, "C1'")]
# Post-insertion residue atoms: [(142, 'P'), (143, 'OP1'), (144, 'OP2'), (145, "O5'"), (146, "C5'"), (147, "C4'"), (148, "O4'"), (149, "C3'"), (150, "O3'"), (151, "C2'"), (152, "C1'"), (153, 'N1'), (154, 'C2'), (155, 'O2'), (156, 'N3'), (157, 'C4'), (158, 'N4'), (159, 'C5'), (160, 'C6')]
# Original trajectory shape: (1, 201, 3)
# xyz1 shape: (1, 153, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 38, 3)
# Concatenated shape: 199
# GGGCG saved as point_mutant_12.pdb
# hello
# Pre-deletion residue atoms : [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'"), (30, 'N9'), (31, 'C8'), (32, 'N7'), (33, 'C5'), (34, 'C6'), (35, 'O6'), (36, 'N1'), (37, 'C2'), (38, 'N2'), (39, 'N3'), (40, 'C4')]
# Pre-insertion residue atoms: [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'")]
# Post-insertion residue atoms: [(19, 'P'), (20, 'OP1'), (21, 'OP2'), (22, "O5'"), (23, "C5'"), (24, "C4'"), (25, "O4'"), (26, "C3'"), (27, "O3'"), (28, "C2'"), (29, "C1'"), (30, 'N1'), (31, 'C2'), (32, 'O2'), (33, 'N3'), (34, 'C4'), (35, 'O4'), (36, 'C5'), (37, 'C7'), (38, 'C6')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 30, 3)
# new_xyz shape: (1, 9, 3)
# xyz2 shape: (1, 158, 3)
# Concatenated shape: 197
# Pre-deletion residue atoms : [(159, 'P'), (160, 'OP1'), (161, 'OP2'), (162, "O5'"), (163, "C5'"), (164, "C4'"), (165, "O4'"), (166, "C3'"), (167, "O3'"), (168, "C2'"), (169, "C1'"), (170, 'N1'), (171, 'C2'), (172, 'O2'), (173, 'N3'), (174, 'C4'), (175, 'N4'), (176, 'C5'), (177, 'C6')]
# Pre-insertion residue atoms: [(159, 'P'), (160, 'OP1'), (161, 'OP2'), (162, "O5'"), (163, "C5'"), (164, "C4'"), (165, "O4'"), (166, "C3'"), (167, "O3'"), (168, "C2'"), (169, "C1'")]
# Post-insertion residue atoms: [(159, 'P'), (160, 'OP1'), (161, 'OP2'), (162, "O5'"), (163, "C5'"), (164, "C4'"), (165, "O4'"), (166, "C3'"), (167, "O3'"), (168, "C2'"), (169, "C1'"), (170, 'N9'), (171, 'C8'), (172, 'N7'), (173, 'C5'), (174, 'C6'), (175, 'N6'), (176, 'N1'), (177, 'C2'), (178, 'N3'), (179, 'C4')]
# Original trajectory shape: (1, 197, 3)
# xyz1 shape: (1, 170, 3)
# new_xyz shape: (1, 10, 3)
# xyz2 shape: (1, 19, 3)
# Concatenated shape: 199
# GTGCG saved as point_mutant_13.pdb
# hello
# Pre-deletion residue atoms : [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'"), (8, 'N9'), (9, 'C8'), (10, 'N7'), (11, 'C5'), (12, 'C6'), (13, 'O6'), (14, 'N1'), (15, 'C2'), (16, 'N2'), (17, 'N3'), (18, 'C4')]
# Pre-insertion residue atoms: [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'")]
# Post-insertion residue atoms: [(0, "O5'"), (1, "C5'"), (2, "C4'"), (3, "O4'"), (4, "C3'"), (5, "O3'"), (6, "C2'"), (7, "C1'"), (8, 'N1'), (9, 'C2'), (10, 'O2'), (11, 'N3'), (12, 'C4'), (13, 'O4'), (14, 'C5'), (15, 'C7'), (16, 'C6')]
# Original trajectory shape: (1, 199, 3)
# xyz1 shape: (1, 8, 3)
# new_xyz shape: (1, 9, 3)
# xyz2 shape: (1, 180, 3)
# Concatenated shape: 197
# Pre-deletion residue atoms : [(17, 'P'), (18, 'OP1'), (19, 'OP2'), (20, "O5'"), (21, "C5'"), (22, "C4'"), (23, "O4'"), (24, "C3'"), (25, "O3'"), (26, "C2'"), (27, "C1'"), (28, 'N1'), (29, 'C2'), (30, 'O2'), (31, 'N3'), (32, 'C4'), (33, 'O4'), (34, 'C5'), (35, 'C7'), (36, 'C6')]
# Pre-insertion residue atoms: [(17, 'P'), (18, 'OP1'), (19, 'OP2'), (20, "O5'"), (21, "C5'"), (22, "C4'"), (23, "O4'"), (24, "C3'"), (25, "O3'"), (26, "C2'"), (27, "C1'")]
# Post-insertion residue atoms: [(17, 'P'), (18, 'OP1'), (19, 'OP2'), (20, "O5'"), (21, "C5'"), (22, "C4'"), (23, "O4'"), (24, "C3'"), (25, "O3'"), (26, "C2'"), (27, "C1'"), (28, 'N1'), (29, 'C2'), (30, 'O2'), (31, 'N3'), (32, 'C4'), (33, 'N4'), (34, 'C5'), (35, 'C6')]
# Original trajectory shape: (1, 197, 3)
# xyz1 shape: (1, 28, 3)
# new_xyz shape: (1, 8, 3)
# xyz2 shape: (1, 160, 3)
# Concatenated shape: 196
# Pre-deletion residue atoms : [(177, 'P'), (178, 'OP1'), (179, 'OP2'), (180, "O5'"), (181, "C5'"), (182, "C4'"), (183, "O4'"), (184, "C3'"), (185, "O3'"), (186, "C2'"), (187, "C1'"), (188, 'N1'), (189, 'C2'), (190, 'O2'), (191, 'N3'), (192, 'C4'), (193, 'N4'), (194, 'C5'), (195, 'C6')]
# Pre-insertion residue atoms: [(177, 'P'), (178, 'OP1'), (179, 'OP2'), (180, "O5'"), (181, "C5'"), (182, "C4'"), (183, "O4'"), (184, "C3'"), (185, "O3'"), (186, "C2'"), (187, "C1'")]
# Post-insertion residue atoms: [(177, 'P'), (178, 'OP1'), (179, 'OP2'), (180, "O5'"), (181, "C5'"), (182, "C4'"), (183, "O4'"), (184, "C3'"), (185, "O3'"), (186, "C2'"), (187, "C1'"), (189, 'N9'), (191, 'C8'), (193, 'N7'), (195, 'C5'), (197, 'C6'), (199, 'N6'), (201, 'N1'), (203, 'C2'), (205, 'N3'), (207, 'C4')]
# Original trajectory shape: (1, 196, 3)
# xyz1 shape: (1, 188, 3)
# new_xyz shape: (1, 10, 3)
# xyz2 shape: (1, 0, 3)
# Concatenated shape: 198
# Pre-deletion residue atoms : [(156, 'P'), (157, 'OP1'), (158, 'OP2'), (159, "O5'"), (160, "C5'"), (161, "C4'"), (162, "O4'"), (163, "C3'"), (164, "O3'"), (165, "C2'"), (166, "C1'"), (167, 'N9'), (168, 'C8'), (169, 'N7'), (170, 'C5'), (171, 'C6'), (172, 'N6'), (173, 'N1'), (174, 'C2'), (175, 'N3'), (176, 'C4')]
# Pre-insertion residue atoms: [(156, 'P'), (157, 'OP1'), (158, 'OP2'), (159, "O5'"), (160, "C5'"), (161, "C4'"), (162, "O4'"), (163, "C3'"), (164, "O3'"), (165, "C2'"), (166, "C1'")]
# Post-insertion residue atoms: [(156, 'P'), (157, 'OP1'), (158, 'OP2'), (159, "O5'"), (160, "C5'"), (161, "C4'"), (162, "O4'"), (163, "C3'"), (164, "O3'"), (165, "C2'"), (166, "C1'"), (167, 'N9'), (168, 'C8'), (169, 'N7'), (170, 'C5'), (171, 'C6'), (172, 'O6'), (173, 'N1'), (174, 'C2'), (175, 'N2'), (176, 'N3'), (177, 'C4')]
# Original trajectory shape: (1, 198, 3)
# xyz1 shape: (1, 167, 3)
# new_xyz shape: (1, 11, 3)
# xyz2 shape: (1, 21, 3)
# Concatenated shape: 199
# TCGCG saved as point_mutant_14.pdb
